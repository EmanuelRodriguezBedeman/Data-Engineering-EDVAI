# %%
import pandas as pd

# %%
link = 'https://dataengineerpublic.blob.core.windows.net/data-engineer/yellow_tripdata_2021-01.parquet'

df = pd.read_parquet(link)
df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2021-01-01 00:30:10   2021-01-01 00:36:12              1.0
# 1         1  2021-01-01 00:51:20   2021-01-01 00:52:19              1.0
# 2         1  2021-01-01 00:43:30   2021-01-01 01:11:06              1.0
# 3         1  2021-01-01 00:15:48   2021-01-01 00:31:01              0.0
# 4         2  2021-01-01 00:31:49   2021-01-01 00:48:21              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           2.10         1.0                  N           142            43
# 1           0.20         1.0                  N           238           151
# 2          14.70         1.0                  N           132           165
# 3          10.60         1.0                  N           138           132
# 4           4.94         1.0                  N            68            33
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
link = 'https://dataengineerpublic.blob.core.windows.net/data-engineer/yellow_tripdata_2021-02.parquet'

df2 = pd.read_parquet(link)
df2.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2021-02-01 00:40:47   2021-02-01 00:48:28              1.0
# 1         1  2021-02-01 00:07:44   2021-02-01 00:20:31              1.0
# 2         1  2021-02-01 00:59:36   2021-02-01 01:24:13              1.0
# 3         2  2021-02-01 00:03:26   2021-02-01 00:16:32              1.0
# 4         2  2021-02-01 00:20:20   2021-02-01 00:24:03              2.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           2.30         1.0                  N           141           226
# 1           1.60         1.0                  N            43           263
# 2           5.30         1.0                  N           114           263
# 3           2.79         1.0                  N           236           229
# 4           0.64         1.0                  N           229           140
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
df[df['airport_fee'] > 0]
# Out:
# Empty DataFrame
# Columns: [VendorID, tpep_pickup_datetime, tpep_dropoff_datetime, passenger_count, trip_distance, RatecodeID, store_and_fwd_flag, PULocationID, DOLocationID, payment_type, fare_amount, extra, mta_tax, tip_amount, tolls_amount, improvement_surcharge, total_amount, congestion_surcharge, airport_fee]
# Index: []

# %%
df['airport_fee'].unique()
# Out:
# array([nan,  0.])
